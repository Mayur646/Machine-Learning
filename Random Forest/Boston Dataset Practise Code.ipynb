# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn import datasets 
boston = datasets.load_boston()
features = pd.DataFrame(boston.data,columns=boston.feature_names)
targets = boston.target
import warnings
warnings.filterwarnings("ignore")

# %%
features
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
data=features

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
X=data
Y=targets

# %%
X.shape
# Out:
# (506, 13)

# %%
Y.shape
# Out:
# (506,)

# %%
X.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=16 :     # as there are 16 columns in the data
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
sns.distplot(targets)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(20,30), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=15 :
        ax = plt.subplot(5,4,plotnumber)
        plt.scatter(X[column],Y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('targets',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
scaler =StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
# Train_test_split (75/25)

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled,Y,test_size=0.25,random_state=101)

# %%
from sklearn.linear_model import LinearRegression #model 
regres=LinearRegression()
regres.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regres.score(X_train,Y_train)
# Out:
# 0.7488713982737203

# %%
regres.score(X_test,Y_test)
# Out:
# 0.7121298549452947

# %%
predy=regres.predict(X_test)
predy
# Out:
# array([40.46905482, 27.48120388, 16.57965361, 17.25752098, 31.39520193,
#        32.64431924, 39.06872397,  8.22059803, 33.38495231,  7.43937604,
#        30.51155682, 13.63023248, 16.45281386, 17.07791868, 25.23724098,
#        20.36845812,  7.25514813, 33.40324566, 28.5487538 , 24.69127874,
#        12.78280414, 20.382864  , 22.50112749, 24.67654135, 34.28272578,
#        18.97331313, 31.91950278, 18.89446329, 26.97890192, 34.44931081,
#        19.71844927, 18.39473031, 37.27286953, 44.79379594, 30.55448818,
#        22.42790327, 16.17607408, 17.87635192,  4.68740441, 30.68341654,
#        24.0987276 , 16.90711632, 34.81074416, 14.03476918, 17.95932426,
#        25.23662931, 30.62148448, 16.32807315, 26.73434495, 22.6765835 ,
#        32.28505539, 37.82975383, 22.58987083, 16.85642003, 30.24978834,
#         0.17824114, 20.35221329, 16.91823126, 22.80128185, 20.94566272,
#        30.88273045,  3.36281546, 15.38435254, 19.81550756, 10.34643199,
#        24.54122716, 24.24164013, 19.8464533 , 18.06516949, 19.19757982,
#        23.79810342, 21.25126516, 23.10512443, 20.12315096, 26.90298162,
#        21.37779673, 36.88174786,  7.73432795, 28.63738861, 17.49237934,
#        15.31431622, 19.67634309, 30.62043619, 17.7771537 , 10.2896669 ,
#        21.71990175, 21.88881898, 33.44828746, 22.70222436, 22.02529174,
#        13.09111777, 11.7989067 , 22.95405124, 33.85230179,  6.27483239,
#        35.31524693,  8.13598679, 31.99349   ,  8.70870956, 20.71772626,
#        32.85144881, 21.40626616, 26.8844797 , 24.51051765, 22.7196353 ,
#        25.38199129, 24.67880717, 30.7387359 , 37.76659419, 32.8979678 ,
#        23.07713292, 36.56871988, 24.28622776, 22.13055314, 30.05725185,
#        27.26488756, 29.20216721, 31.57273988, 26.50681599, 29.44985672,
#        16.99065125, 20.40014451, 21.71508591, 36.56374675, 24.9442192 ,
#        23.34115694, 15.21882621])

# %%
from sklearn.metrics import r2_score
r_squared=r2_score(Y_test, predy)
r_squared
# Out:
# 0.7121298549452947

# %%
#mse
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y_test,predy)
mse
# Out:
# 30.119048511444173

# %%
#rmse
from math import sqrt
rmse=sqrt(mean_squared_error(Y_test,predy))
rmse
# Out:
#        15.32945309, 23.4626431 , 20.2669167 , 34.26218634, 19.99774315,
#        20.12878195, 16.7109705 , 23.90185186, 25.6562079 , 21.93688863,
#        23.54138205, 18.9008651 , 21.09900857, 20.71499715])

# %%
mse_train=mean_squared_error(Y_train,pred_y)
print(mse_train)
rmse_train=sqrt(mean_squared_error(Y_train,pred_y))
print(rmse_train)
# Out:
# 19.348254756255848
# 4.398665110718915

# %% [markdown]
# # Regularization

# %%
def adj_r2(X,Y,model):
    r2 = model.score(X,Y)
    n = X.shape[0]
    p = X.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
regres.score(X_train,Y_train)*100 #R2 for training
# Out:
# 74.88713982737202

# %%
adj_r2(X_train,Y_train,regres)*100 #adj R2 for training
# Out:
# 73.99270919108665

# %% [markdown]
# # Training Accurtacy
# #for training data
# r2=74.88% and adj r2= 73.99%

# %%
regres.score(X_test,Y_test)*100 #R2 for testing
# Out:
# 71.21298549452946

# %%
adj_r2(X_test,Y_test,regres)*100
# Out:
# 67.90120506469657

# %% [markdown]
# # Test Accurtacy
# #for testing data
# r2=71.21% and adj r2= 67.9%

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100,101,220,219,215,210,207,208,206,210]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X,Y)
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 206}
# -29.845425033808272

# %%
Ridge_alpha=206

# %%
ridge_reg = Ridge(Ridge_alpha)
ridge_reg.fit(X_train, Y_train)
# Out:
# Ridge(alpha=206)

# %%
r2=ridge_reg.score(X_train,Y_train)
print(r2)
# Out:
# 0.6834349264895959

# %%
adj_r2(X_train,Y_train,ridge_reg)
# Out:
# 0.672160006063198

# %%
adj_r2(X_test,Y_test,ridge_reg)
# Out:
# 0.6154449996654969

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100,200,206,300,1.1,0.9,0.8,0.7,0.5,0.4,0.3,0.2,0.33]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X,Y)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 0.33}
# -34.44114847278196

# %%
lasso_alpha=0.33

# %%
lasso_reg = Lasso(lasso_alpha)
lasso_reg.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.33)

# %%
r2=lasso_reg.score(X_train,Y_train)
print(r2)
# Out:
# 0.7161244880397923

# %%
adj_r2(X_train,Y_train,lasso_reg)
# Out:
# 0.7060138533672371

# %%
adj_r2(X_test,Y_test,lasso_reg)
# Out:
# 0.6387511485370054

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model  import  ElasticNetCV
elasticCV = ElasticNetCV(alphas = None, cv =5)

elasticCV.fit(X_train, Y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
elastic_alpha=elasticCV.alpha_
elastic_alpha
# Out:
# 0.05100215567417365

# %%
from sklearn.linear_model  import  ElasticNet
elasticnet_reg = ElasticNet(alpha = elastic_alpha)
elasticnet_reg.fit(X_train, Y_train)
# Out:
# ElasticNet(alpha=0.05100215567417365)

# %%
elasticnet_reg.score(X_train, Y_train)
# Out:
# 0.7464075027530694

# %%
elasticnet_reg.score(X_test, Y_test)
# Out:
# 0.7090351688691947

# %%
adj_r2(X_train,Y_train,elasticnet_reg)
# Out:
# 0.7373754412072884

# %%
adj_r2(X_test, Y_test,elasticnet_reg)
# Out:
# 0.6755613387391021

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_train,Y_train)
# Out:
# 0.9801967921032831

# %%
forest.score(X_test,Y_test)
# Out:
# 0.8722113405238885

# %% [markdown]
# there is lots of overfitting in the model

# %% [markdown]
# ## Hyper-Parameter tuning

# %%
grid_param = {
    "n_estimators" : [90,100,115,130],
    'max_depth' : range(2,20,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features' : ['auto','log2']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=forest,param_grid=grid_param,cv=5,n_jobs =-1,verbose = 3)

# %%
grid_search.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10368 candidates, totalling 51840 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 5400 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 6264 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 8184 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 9240 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 10360 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=-1)]: Done 11544 tasks      | elapsed: 27.2min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 30.6min
# [Parallel(n_jobs=-1)]: Done 14104 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 15480 tasks      | elapsed: 37.1min
# [Parallel(n_jobs=-1)]: Done 16920 tasks      | elapsed: 40.4min
# [Parallel(n_jobs=-1)]: Done 18424 tasks      | elapsed: 44.3min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 48.0min
# [Parallel(n_jobs=-1)]: Done 21624 tasks      | elapsed: 52.8min
# [Parallel(n_jobs=-1)]: Done 23320 tasks      | elapsed: 56.9min
# [Parallel(n_jobs=-1)]: Done 25080 tasks      | elapsed: 61.7min
# [Parallel(n_jobs=-1)]: Done 26904 tasks      | elapsed: 66.3min
# [Parallel(n_jobs=-1)]: Done 28792 tasks      | elapsed: 70.7min
# [Parallel(n_jobs=-1)]: Done 30744 tasks      | elapsed: 75.5min
# [Parallel(n_jobs=-1)]: Done 32760 tasks      | elapsed: 80.1min
# [Parallel(n_jobs=-1)]: Done 34840 tasks      | elapsed: 84.9min
# [Parallel(n_jobs=-1)]: Done 36984 tasks      | elapsed: 137.4min
# [Parallel(n_jobs=-1)]: Done 39192 tasks      | elapsed: 143.5min
# [Parallel(n_jobs=-1)]: Done 41464 tasks      | elapsed: 149.2min
# [Parallel(n_jobs=-1)]: Done 43800 tasks      | elapsed: 154.6min
# [Parallel(n_jobs=-1)]: Done 46200 tasks      | elapsed: 160.2min
# [Parallel(n_jobs=-1)]: Done 48664 tasks      | elapsed: 166.2min
# [Parallel(n_jobs=-1)]: Done 51192 tasks      | elapsed: 213.1min
# [Parallel(n_jobs=-1)]: Done 51840 out of 51840 | elapsed: 214.5min finished
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': range(2, 20),
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'n_estimators': [90, 100, 115, 130]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 19,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 115}

# %%
forest = RandomForestRegressor(max_depth= 10,
 max_features= 'log2',
 min_samples_leaf= 5,
 min_samples_split= 4,
 n_estimators= 110)

# %%
forest.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_features='log2', min_samples_leaf=5,
#                       min_samples_split=4, n_estimators=110)

# %%
forest.score(X_train,Y_train)
# Out:
# 0.8979418347186824

# %%
forest.score(X_test,Y_test)
# Out:
# 0.8156433570579935

# %% [markdown]
# after hyper parameter tuning we get the training accuracy as 89.79% and testing accuracy as 81.56%
